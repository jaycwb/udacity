# %%
#CARREGA A(S) BIBLIOTECAS
import pandas as pd

# %%
#CARREGA O ARQUIVO QUE CONTEM A LOCALIZAÇÃO DAS PLANTAS DE PRODUCAO DE ÓLEO LUBRIFICANTE EM SOLO BRASILEIRO
plantas_producao = pd.read_excel("../data/boletim_1/Anexo_E.xlsx", sheetname="30-Mapa_Planta_Prod_OLAC")
plantas_producao.head()
# Out:
#               CNPJ                                           Produtor  \
# 0   57941890000153                  AGECOM PRODUTOS DE PETRÓLEO LTDA.
# 1    3439153000128                            BIOLUB QUÍMICA LTDA -ME
# 2   33194978000190                                CASTROL BRASIL LTDA
# 3   45036670000104                     CHEMLUB PRODUTOS QUÍMICOS LTDA
# 4    5524572001084                 CHEVRON BRASIL LUBRIFICANTES LTDA.
# 5    7129683000120  CONDAT LUBRIFICANTES DO BRASIL INDÚSTRIA E COM...
# 6   33000092003850          COSAN LUBRIFICANTES E ESPECIALIDADES S.A.
# 7   18235762000132                       DAIDO QUÍMICA DO BRASIL LTDA
# 8   68919158000101                       DNC INDUSTRIAL CAMPINAS LTDA
# 9    5092901000921                     DUNAX LUBRIFICANTES LTDA. - ME
# 10  62417282000184      ELVIN LUBRIFICANTES INDÚSTRIA E COMÉRCIO LTDA
# 11    696951000228  ENERGIS8 INDÚSTRIA E COMÉRCIO DE LUBRIFICANTES...
# 12  84527274000123  ETERNAL INDÚSTRIA, COMÉRCIO, SERVIÇOS E TRATAM...
# 13   3477131000152                EVOLUB EVOLUÇÃO LUBRIFICANTES LTDA.
# 14   5853347000281         FÁBRICA-QUÍMICA PETRÓLEO E DERIVADOS LTDA.
# 15    384068000111  FALUB INDÚSTRIA E COMÉRCIO DE LUBRIFICANTES LTDA.
# 16  43995646000169                FUCHS LUBRIFICANTES DO BRASIL LTDA.
# 17    248414000134      G.C INDUSTRIAL IMPORTADORA E EXPORTADORA LTDA
# 18  53382545000176              HORTON LUBRIFICANTES INDUSTRIAIS LTDA
# 19  57490245000161                               HOUGHTON BRASIL LTDA
# 20    974369000103              ICOLUB INDÚSTRIA DE LUBRIFICANTES S.A
# 21   4338434000157                INCOL-LUB INDÚSTRIA E COMÉRCIO LTDA
# 22  77575330000482          INGRAX INDÚSTRIA E COMÉRCIO DE GRAXAS S/A
# 23   7830331000106  INTERLUB BRASIL INDUSTRIA E COMERCIO DE ÓLEO A...
# 24  33337122014187                  IPIRANGA PRODUTOS DE PETRÓLEO S.A
# 25  33337122000127                  IPIRANGA PRODUTOS DE PETRÓLEO S.A
# 26   3102205000176                         ITW CHEMICAL PRODUCTS LTDA
# 27   4238156000166                         KARTER LUBRIFICANTES LTDA.
# 28   3313366000109                      KATION RAIDEN DO BRASIL LTDA.
# 29   3099254000105                             KELPEN OIL BRASIL LTDA
# ..             ...                                                ...
# 34  59160689000164                         LUCHETI LUBRIFICANTES LTDA
# 35  46201083000188                           LWART LUBRIFICANTES LTDA
# 36   5481829000177                      MAFRA LUBRIFICANTES LTDA - ME
# 37   2737439000399                MARCIO BENEDITO VECCHI EIRELI - EPP
# 38   6160091000109         MENZOIL INDUSTRIA DE LUBRIFICANTES LTDA ME
# 39   3122996000287                             MOLECULAR BRASIL LTDA.
# 40   3805416000175  PACKBLEND INDUSTRIA E COMERCIO DE LUBRIFICANTE...
# 41  51866804000109                             PAX LUBRIFICANTES LTDA
# 42  34274233026675                       PETROBRAS DISTRIBUIDORA S.A.
# 43  73300949000180               PETROLEU MINERALE LUBRIFICANTES LTDA
# 44   3613421000186                        PETRONAS LUBRIFICANTES S.A.
# 45  11378430000168                   POLY PETRO LUBRIFICANTES LTDA ME
# 46  61531620001709  PROMAX PRODUTOS MÁXIMOS INDÚSTRIA E COMÉRCIO S.A.
# 47    999042000188           QUAKER CHEMICAL INDÚSTRIA E COMÉRCIO S.A
# 48  62227509002920                         QUANTIQ DISTRIBUIDORA LTDA
# 49  68377894000177                     QUÍMICA INDUSTRIAL SUPPLY LTDA
# 50   1084176000131                         REGELUB LUBRIFICANTES LTDA
# 51   4040537000136  SAFRA QUÍMICA INDÚSTRIA E COMÉRCIO DE LUBRIFIC...
# 52  64645096000128               SENDER OIL INDÚSTRIA E COMÉRCIO LTDA
# 53  10456016000248                        SHELL BRASIL PETRÓLEO LTDA.
# 54  62859657000166  SIVA SIROLL PRODUTOS QUÍMICOS E LUBRIFICANTES ...
# 55   4521158000168  SR III INDÚSTRIA E COMÉRCIO DE LUBRIFICANTES LTDA
# 56  61465597000134              TAMCO LUBRIFICANTES E DERIVADOS LTDA.
# 57    616970000116  TECLUB INDÚSTRIA E COMÉRCIO DE LUBRIFICANTES L...
# 58  41879800000101                   TECNO INDÚSTRIA E COMÉRCIO LTDA.
# 59   4608635000127                               TEXSA DO BRASIL LTDA
# 60    200296000194  TG Indústria e Comércio de Lubrificantes e Gra...
# 61  61923017000105  TIRRENO INDÚSTRIA E COMÉRCIO DE PRODUTOS QUÍMI...
# 62  71770689000181                TOTAL LUBRIFICANTES DO BRASIL LTDA.
# 63   5131638000185                    ULTRAX LUBRIFICANTES LTDA - EPP
#
#                  Município  UF
# 0                     MAUA  SP
# 1                 SOROCABA  SP
# 2           RIO DE JANEIRO  RJ
# 3                 VALINHOS  SP
# 4          DUQUE DE CAXIAS  RJ
# 5    BOM JESUS DOS PERDOES  SP
# 6           RIO DE JANEIRO  RJ
# 7                 CONTAGEM  MG
# 8              HORTOLANDIA  SP
# 9   SAO GONCALO DOS CAMPOS  BA
# 10         FRANCO DA ROCHA  SP
# 11                   IPERO  SP
# 12                  MANAUS  AM
# 13                     UBA  MG
# 14                  CUIABA  MT
# 15                     ITU  SP
# 16                 BARUERI  SP
# 17                  OSASCO  SP
# 18               SAO PAULO  SP
# 19                    MAUA  SP
# 20          RIO DE JANEIRO  RJ
# 21             PEDERNEIRAS  SP
# 22         DUQUE DE CAXIAS  RJ
# 23               GUARULHOS  SP
# 24          RIO DE JANEIRO  RJ
# 25          RIO DE JANEIRO  RJ
# 26          EMBU DAS ARTES  SP
# 27                 JACAREI  SP
# 28                 DIADEMA  SP
# 29                   ARUJA  SP
# ..                     ...  ..
# 34               SAO PAULO  SP
# 35        LENCOIS PAULISTA  SP
# 36         MOGI DAS CRUZES  SP
# 37                     ITU  SP
# 38                LOUVEIRA  SP
# 39          RIO DE JANEIRO  RJ
# 40                 DIADEMA  SP
# 41                CAMPINAS  SP
# 42         DUQUE DE CAXIAS  RJ
# 43           CAXIAS DO SUL  RS
# 44                CONTAGEM  MG
# 45               GUARULHOS  SP
# 46                 CAJAMAR  SP
# 47          RIO DE JANEIRO  RJ
# 48               GUARULHOS  SP
# 49                 TAPIRAI  SP
# 50                  LORENA  SP
# 51               GUARULHOS  SP
# 52              SAO CARLOS  SP
# 53          RIO DE JANEIRO  RJ
# 54               SAO PAULO  SP
# 55                ROLANDIA  PR
# 56         FRANCO DA ROCHA  SP
# 57    SAO JOSE DOS PINHAIS  PR
# 58          BELO HORIZONTE  MG
# 59                UMUARAMA  PR
# 60               ARAUCARIA  PR
# 61                 DIADEMA  SP
# 62         PINDAMONHANGABA  SP
# 63             PEDERNEIRAS  SP
#
# [64 rows x 4 columns]

# %%
#CRIA UM DICIONÁRIO PARA ARMAZENAR O UF DAS PLANTAS DE PRODUCAO
empresa_prod_uf = {}

for index,row in plantas_producao.iterrows():
    empresa = row['Produtor']
    if empresa not in empresa_prod_uf:
        empresa_prod_uf[empresa] = row['UF']
    else:
    #CASO UMA EMPRESA TENHA MAIS DE UMA PLANTA INDUSTRIAL, IMPRIMIR O NOME DA EMPRESA E A UF ONDE A PLANTA ESTÁ.    
        print(empresa+" - "+row['UF']) # A IPIERANGA NESSE CASO POSSUI DUAS PLANTAS NO MESMO ESTADO (RJ)
        continue
# Out:
# IPIRANGA PRODUTOS DE PETRÓLEO S.A - RJ

# %%
#Vendas nacionais de OLAC pelos Produtores e Importadores
#A COLUNA PRODUTOR-IMPORTADOR POSSUI A INFORMAÇÃÕ DE UMA EMPRESA QUE DECLARA UMA OPERAÇÃO DE COMERCIALIZAÇÃO À ANP.
#TODAVIA, ESSE PRODUTO COMERCIALIZADO PODE TER A SEGUINTE ORIGEM:
### 1. SER PRODUZIDO EM PLANTA INDUSTRIAL PRÓPRIA EM SOLO BRASILEIRO.
### 2. SER PRODUZIDO EM PLANTA INDUSTRIAL DE TERCEIRO EM SOLO BRASILEIRO.
### 3. SER PRODUZID FORA DO BRASIL (PLANTA PRÓPRIA OU NÃO.)
vendas = pd.read_excel("../data/boletim_1/Anexo_H.xlsx", sheetname="41-Vendas OLAC Geral")
vendas.head(5)
# Out:
#       Data  Cód Regulado ANP  \
# 0  12/2016            200296
# 1  12/2016            200296
# 2  12/2016            200296
# 3  12/2016            200296
# 4  12/2016            200296
#
#                                  Produtor-Importador  Código do Produto  \
# 0  TG Indústria e Comércio de Lubrificantes e Gra...          620101002
# 1  TG Indústria e Comércio de Lubrificantes e Gra...          620101002
# 2  TG Indústria e Comércio de Lubrificantes e Gra...          620501001
# 3  TG Indústria e Comércio de Lubrificantes e Gra...          620501001
# 4  TG Indústria e Comércio de Lubrificantes e Gra...          620501001
#
#                    Descrição do Produto Região do Destinatário  \
# 0  ENGRENAGENS E SISTEMAS CIRCULATÓRIOS                    SUL
# 1  ENGRENAGENS E SISTEMAS CIRCULATÓRIOS                    SUL
# 2                            Ciclo Otto                    SUL
# 3                            Ciclo Otto                    SUL
# 4                            Ciclo Otto                    SUL
#
#   UF do Destinatário  Volume-Litros
# 0                 PR           9828
# 1                 SC            800
# 2                 PR           3685
# 3                 RS            480
# 4                 SC           5040

# %%
#TROCAR O NOME DA EMPRESA (PRODUTOR-IMPORTADOR) PELO UF ONDE ESTÁ LOCALIZADO A PLANTA DE PRODUÇÃO.
vendas['Produtor-Importador'] = vendas['Produtor-Importador'].map(empresa_prod_uf)

# %%
#NÚMERO DE REGISTROS DE DECLARAÇÃO DE COMERCIALIZAÇÃO DE EMPRESAS QUE NÃO PRODUZIRAM EM PLANTA PRÓPRIA NO BRASIL OU SÃO 
#CONSIDERADAS IMPORTADORAS
vendas['Produtor-Importador'].isnull().sum()
# Out:
# 9848

# %%
#PERCENTUAL DE REGISTROS DE DECLARAÇÃO DE COMERCIALIZAÇÃO QUE SÃO DE EMPRESAS QUE NÃO PRODUZIRAM EM PLANTA PRÓPRIA NO BRASIL OU SÃO 
#CONSIDERADAS IMPORTADORAS
str(round(vendas['Produtor-Importador'].isnull().sum()/vendas['Produtor-Importador'].shape[0]*100,2))+"%"
# Out:
# '26.14%'

# %%
#SOMA DOS VOLUMES DE COMERCIALIZACAO DE EMPRESAS DETENTORAS & PRODUTORAS
count_volume_detentor_produtor = 0

#SOMA DOS VOLUMES DE EMPRESAS QUE SÃO DETENTORAS/TERCERIZADORAS OU DETENTORAS/IMPORTADORAS
count_volume_outros = 0
for index,row in vendas.iterrows():
    if type(row['Produtor-Importador']) != str:
        count_volume_outros += row['Volume-Litros']
    else:
        count_volume_detentor_produtor += row['Volume-Litros']

# %%
print("Volume total de empresas Detentoras/Produtoras "+str(count_volume_detentor_produtor/1000)+ " m³")
print("Volume total de empresas Detentoras/Tercerizadoras/Importadoras "+str(count_volume_outros/1000)+ " m³")
# Out:
# Volume total de empresas Detentoras/Produtoras 1131775.986 m³
# Volume total de empresas Detentoras/Tercerizadoras/Importadoras 97916.397 m³

# %%
#PERCENTUAL EM VOLUME DOS REGISTROS QUE NÃO PODE SE INFERIR QUAL A ORIGEM DA PRODUÇÃO, APENAS O DESTINATÁRIO.
str(round(count_volume_outros/(count_volume_outros+count_volume_detentor_produtor)*100,2))+"%"
# Out:
# '7.96%'

# %%
#LISTA PARA ABRIGAR O INDEX DOS REGISTROS QUE NÃO POSSUEM A IDENTIFICAÇÃO DA UF DA ORIGEM DA PRODUÇÃO
list_index_nan = []
for index,row in vendas.iterrows():
    if type(row['Produtor-Importador']) != str:
        list_index_nan.append(index)

# %%
#DELETAR DO DATAFRAME DOS OS REGISTROS QUE NÃO POSSUEM A IDENTIFICAÇÃO DA UF DA ORIGEM DA PRODUÇÃO
vendas_uf = vendas[vendas['Produtor-Importador'].notnull()]

# %%
#RESETAR O INDEX DO DATAFRAME
vendas_uf.reset_index(inplace=True)
del vendas_uf['index']

# %%
vendas_uf.columns = ['Data', 'Cód Regulado ANP', 'UF_origem',
       'Código do Produto', 'Descrição do Produto', 'Região do Destinatário',
       'UF_destino', 'Volume-Litros']

# %%
vendas_uf
# Out:
#           Data  Cód Regulado ANP UF_origem  Código do Produto  \
# 0      12/2016            200296        PR          620101002
# 1      12/2016            200296        PR          620101002
# 2      12/2016            200296        PR          620501001
# 3      12/2016            200296        PR          620501001
# 4      12/2016            200296        PR          620501001
# 5      12/2016            200296        PR          620501002
# 6      12/2016            200296        PR          620503001
# 7      12/2016            200296        PR          620503001
# 8      12/2016            200296        PR          620503001
# 9      12/2016            200296        PR          620601004
# 10     12/2016            200296        PR          620601004
# 11     12/2016            384068        SP          620101002
# 12     12/2016            384068        SP          620503001
# 13     12/2016            384068        SP          620601004
# 14     12/2016            384068        SP          620601004
# 15     12/2016            616970        PR          620501001
# 16     12/2016            616970        PR          620501001
# 17     12/2016            616970        PR          620501001
# 18     12/2016            616970        PR          620501001
# 19     12/2016            616970        PR          620501001
# 20     12/2016            616970        PR          620501001
# 21     12/2016            616970        PR          620501001
# 22     12/2016            616970        PR          620501001
# 23     12/2016            616970        PR          620501001
# 24     12/2016            616970        PR          620501001
# 25     12/2016            616970        PR          620501001
# 26     12/2016            616970        PR          620501001
# 27     12/2016            616970        PR          620501001
# 28     12/2016            616970        PR          620501001
# 29     12/2016            616970        PR          620501002
# ...        ...               ...       ...                ...
# 27799  01/2016        5034274233        RJ          620601004
# 27800  01/2016        5034274233        RJ          620601004
# 27801  01/2016        5034274233        RJ          620601004
# 27802  01/2016        5034274233        RJ          620601004
# 27803  01/2016        5034274233        RJ          620601004
# 27804  01/2016        5034274233        RJ          620601004
# 27805  01/2016        5034274233        RJ          620601004
# 27806  01/2016        5034274233        RJ          620601004
# 27807  01/2016        5034274233        RJ          620601004
# 27808  01/2016        5034274233        RJ          620601004
# 27809  01/2016        5034274233        RJ          620601004
# 27810  01/2016        5034274233        RJ          620601004
# 27811  01/2016        5034274233        RJ          620601004
# 27812  01/2016        5034274233        RJ          620601004
# 27813  01/2016        5034274233        RJ          620601004
# 27814  01/2016        5034274233        RJ          620601004
# 27815  01/2016        5034274233        RJ          620601004
# 27816  01/2016        5034274233        RJ          620601004
# 27817  01/2016        9903122996        RJ          620101002
# 27818  01/2016        9903122996        RJ          620301001
# 27819  01/2016        9903122996        RJ          620501001
# 27820  01/2016        9903122996        RJ          620501001
# 27821  01/2016        9903122996        RJ          620501001
# 27822  01/2016        9903122996        RJ          620501001
# 27823  01/2016        9903122996        RJ          620501002
# 27824  01/2016        9903122996        RJ          620502001
# 27825  01/2016        9903122996        RJ          620503001
# 27826  01/2016        9903122996        RJ          620601004
# 27827  01/2016        9903122996        RJ          620601004
# 27828  01/2016        9903122996        RJ          620601004
#
#                        Descrição do Produto Região do Destinatário UF_destino  \
# 0      ENGRENAGENS E SISTEMAS CIRCULATÓRIOS                    SUL         PR
# 1      ENGRENAGENS E SISTEMAS CIRCULATÓRIOS                    SUL         SC
# 2                                Ciclo Otto                    SUL         PR
# 3                                Ciclo Otto                    SUL         RS
# 4                                Ciclo Otto                    SUL         SC
# 5                              Ciclo Diesel                    SUL         PR
# 6       TRANSMISSÕES E SISTEMAS HIDRÁULICOS                    SUL         PR
# 7       TRANSMISSÕES E SISTEMAS HIDRÁULICOS                    SUL         RS
# 8       TRANSMISSÕES E SISTEMAS HIDRÁULICOS                    SUL         SC
# 9       Outros Óleos Lubrificantes Acabados                    SUL         PR
# 10      Outros Óleos Lubrificantes Acabados                    SUL         SC
# 11     ENGRENAGENS E SISTEMAS CIRCULATÓRIOS                SUDESTE         SP
# 12      TRANSMISSÕES E SISTEMAS HIDRÁULICOS                SUDESTE         SP
# 13      Outros Óleos Lubrificantes Acabados           CENTRO OESTE         GO
# 14      Outros Óleos Lubrificantes Acabados                SUDESTE         SP
# 15                               Ciclo Otto           CENTRO OESTE         DF
# 16                               Ciclo Otto           CENTRO OESTE         GO
# 17                               Ciclo Otto               NORDESTE         BA
# 18                               Ciclo Otto               NORDESTE         CE
# 19                               Ciclo Otto               NORDESTE         MA
# 20                               Ciclo Otto               NORDESTE         PB
# 21                               Ciclo Otto               NORDESTE         PE
# 22                               Ciclo Otto               NORDESTE         PI
# 23                               Ciclo Otto               NORDESTE         RN
# 24                               Ciclo Otto               NORDESTE         SE
# 25                               Ciclo Otto                SUDESTE         SP
# 26                               Ciclo Otto                    SUL         PR
# 27                               Ciclo Otto                    SUL         RS
# 28                               Ciclo Otto                    SUL         SC
# 29                             Ciclo Diesel           CENTRO OESTE         DF
# ...                                     ...                    ...        ...
# 27799   Outros Óleos Lubrificantes Acabados               NORDESTE         MA
# 27800   Outros Óleos Lubrificantes Acabados               NORDESTE         PB
# 27801   Outros Óleos Lubrificantes Acabados               NORDESTE         PE
# 27802   Outros Óleos Lubrificantes Acabados               NORDESTE         PI
# 27803   Outros Óleos Lubrificantes Acabados               NORDESTE         RN
# 27804   Outros Óleos Lubrificantes Acabados               NORDESTE         SE
# 27805   Outros Óleos Lubrificantes Acabados                  NORTE         AM
# 27806   Outros Óleos Lubrificantes Acabados                  NORTE         PA
# 27807   Outros Óleos Lubrificantes Acabados                  NORTE         RO
# 27808   Outros Óleos Lubrificantes Acabados                  NORTE         RR
# 27809   Outros Óleos Lubrificantes Acabados                  NORTE         TO
# 27810   Outros Óleos Lubrificantes Acabados                SUDESTE         ES
# 27811   Outros Óleos Lubrificantes Acabados                SUDESTE         MG
# 27812   Outros Óleos Lubrificantes Acabados                SUDESTE         RJ
# 27813   Outros Óleos Lubrificantes Acabados                SUDESTE         SP
# 27814   Outros Óleos Lubrificantes Acabados                    SUL         PR
# 27815   Outros Óleos Lubrificantes Acabados                    SUL         RS
# 27816   Outros Óleos Lubrificantes Acabados                    SUL         SC
# 27817  ENGRENAGENS E SISTEMAS CIRCULATÓRIOS                SUDESTE         RJ
# 27818         Óleos Lubrificantes Marítimos                SUDESTE         RJ
# 27819                            Ciclo Otto               NORDESTE         PE
# 27820                            Ciclo Otto                SUDESTE         RJ
# 27821                            Ciclo Otto                SUDESTE         SP
# 27822                            Ciclo Otto                    SUL         RS
# 27823                          Ciclo Diesel                SUDESTE         RJ
# 27824                      Motores 2 tempos                SUDESTE         RJ
# 27825   TRANSMISSÕES E SISTEMAS HIDRÁULICOS                SUDESTE         RJ
# 27826   Outros Óleos Lubrificantes Acabados                SUDESTE         MG
# 27827   Outros Óleos Lubrificantes Acabados                SUDESTE         SP
# 27828   Outros Óleos Lubrificantes Acabados                    SUL         RS
#
#        Volume-Litros
# 0               9828
# 1                800
# 2               3685
# 3                480
# 4               5040
# 5               1184
# 6              17764
# 7              13800
# 8              71772
# 9              30519
# 10              2200
# 11              7220
# 12            117400
# 13            180000
# 14             15840
# 15             29280
# 16             15720
# 17              9600
# 18              4560
# 19              1920
# 20             13160
# 21             12600
# 22              3000
# 23             11640
# 24              2640
# 25               360
# 26             30552
# 27             28240
# 28             53912
# 29              2900
# ...              ...
# 27799           1580
# 27800           2200
# 27801          17840
# 27802            740
# 27803           6900
# 27804           5020
# 27805           4340
# 27806          29400
# 27807           3300
# 27808            200
# 27809           1100
# 27810          24026
# 27811          32040
# 27812         108551
# 27813         336477
# 27814           8980
# 27815          13760
# 27816           8980
# 27817            240
# 27818             48
# 27819          12108
# 27820           6144
# 27821          17506
# 27822           3466
# 27823           1680
# 27824             68
# 27825           1584
# 27826          16390
# 27827           9692
# 27828           1722
#
# [27829 rows x 8 columns]

# %%
#CRIA UMA LISTA COM TODAS AS UF'S
lista_UF = vendas_uf['UF_destino'].unique().tolist()

#ORGANIZA A LISTA POR ORDEM ALFABÉTICA
lista_UF.sort()

# %%
#LISTA DE DICIONÁRIOS
lista_dict_uf = []
for uf in lista_UF:
    dict_uf = {"name": uf}
    lista_dict_uf.append(dict_uf)

# %%
#CRIAR UM OBJETO PARA CRIAR O DIAGRAMA DE SANKEY

json = { "nodes" : lista_dict_uf , "links" : [] }

# %%
#CRIA UM DICIONÁRIO PARA CODIFICAR AS UF'S
uf_codigo = {}
count = 0

for uf in lista_UF:
    uf_codigo[uf] = count
    count += 1

# %%
#CODIFICA AS COLUNAS UTILIZANDO O DICIONÁRIO uf_codigo
vendas_uf['UF_origem'] = vendas_uf['UF_origem'].map(uf_codigo)
vendas_uf['UF_destino'] = vendas_uf['UF_destino'].map(uf_codigo)
# Out:
# C:\Users\ferraz\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\ferraz\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
#VERIFICACÃO DA CODIFICACAO
vendas_uf.head()
# Out:
#       Data  Cód Regulado ANP  UF_origem  Código do Produto  \
# 0  12/2016            200296         17          620101002
# 1  12/2016            200296         17          620101002
# 2  12/2016            200296         17          620501001
# 3  12/2016            200296         17          620501001
# 4  12/2016            200296         17          620501001
#
#                    Descrição do Produto Região do Destinatário  UF_destino  \
# 0  ENGRENAGENS E SISTEMAS CIRCULATÓRIOS                    SUL          17
# 1  ENGRENAGENS E SISTEMAS CIRCULATÓRIOS                    SUL          23
# 2                            Ciclo Otto                    SUL          17
# 3                            Ciclo Otto                    SUL          22
# 4                            Ciclo Otto                    SUL          23
#
#    Volume-Litros
# 0           9828
# 1            800
# 2           3685
# 3            480
# 4           5040
